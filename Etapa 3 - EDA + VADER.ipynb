# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
data = pd.read_csv('appl_1_amazon_pc.csv') #Adicionando o Dataset

# %%
data.head(10) #Primeira visualização
# Out:
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US     11555559  R1QXC7AHHJBQ3O  B00IKPX4GY         2693241
# 1          US     31469372  R175VSRV6ZETOP  B00IKPYKWG         2693241
# 2          US     26843895  R2HRFF78MWGY19  B00IKPW0UA         2693241
# 3          US     19844868   R8Q39WPKYVSTX  B00LCHSHMS         2693241
# 4          US      1189852  R3RL4C8YP2ZCJL  B00IKPZ5V6         2693241
# 5          US     14239730  R15B8KUCTZEIAZ  B00IKPYKWG         2693241
# 6          US     44445848   RH819AVFZQQJD  B00IKPYKWG         2693241
# 7          US     28328595  R3AUPGXXHD3Y2K  B00IKPZ5V6         2693241
# 8          US     13496210  R39KKR7TWFHENK  B00LCHRQL6         2693241
# 9          US     16092745  R2TPJAFH6DBEEZ  B00IKPYKWG         2693241
#
#                            product_title product_category  star_rating  \
# 0  Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            5
# ...

# %%
data.shape # linhas e colunas
# Out:
# (30846, 16)

# %%
data.columns #Colunas no Dataset
# Out:
# Index(['marketplace', 'customer_id', 'review_id', 'product_id',
#        'product_parent', 'product_title', 'product_category', 'star_rating',
#        'helpful_votes', 'total_votes', 'vine', 'verified_purchase',
#        'review_headline', 'review_body', 'review_date', 'sentiment'],
#       dtype='str')

# %%
data.info() # Verificação de tipos e quantidade de colunas
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30846 entries, 0 to 30845
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   marketplace        30846 non-null  str
#  1   customer_id        30846 non-null  int64
#  2   review_id          30846 non-null  str
#  3   product_id         30846 non-null  str
#  4   product_parent     30846 non-null  int64
#  5   product_title      30846 non-null  str
#  6   product_category   30846 non-null  str
#  7   star_rating        30846 non-null  int64
#  8   helpful_votes      30846 non-null  int64
#  9   total_votes        30846 non-null  int64
#  10  vine               30846 non-null  str
#  11  verified_purchase  30846 non-null  str
#  12  review_headline    30844 non-null  str
#  13  review_body        30842 non-null  str
#  14  review_date        30846 non-null  str
#  15  sentiment          30846 non-null  int64
# dtypes: int64(6), str(10)
# memory usage: 3.8 MB

# %%
data = data.dropna() #Removendo os dados nulos, caso existam

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 30840 entries, 0 to 30845
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   marketplace        30840 non-null  str
#  1   customer_id        30840 non-null  int64
#  2   review_id          30840 non-null  str
#  3   product_id         30840 non-null  str
#  4   product_parent     30840 non-null  int64
#  5   product_title      30840 non-null  str
#  6   product_category   30840 non-null  str
#  7   star_rating        30840 non-null  int64
#  8   helpful_votes      30840 non-null  int64
#  9   total_votes        30840 non-null  int64
#  10  vine               30840 non-null  str
#  11  verified_purchase  30840 non-null  str
#  12  review_headline    30840 non-null  str
#  13  review_body        30840 non-null  str
#  14  review_date        30840 non-null  str
#  15  sentiment          30840 non-null  int64
# dtypes: int64(6), str(10)
# memory usage: 4.0 MB

# %%
for col in data.columns: #Foi visualizado que os dados não precisam de tratamento
    print(data[col].fillna('null').value_counts())
    print()
    print()
# Out:
# marketplace
# US    30840
# Name: count, dtype: int64
#
#
# customer_id
# 5120952     2
# 11555559    1
# 31469372    1
# 26843895    1
# 19844868    1
#            ..
# 44834233    1
# 13376158    1
# 40485963    1
# 33485035    1
# 7015231     1
# Name: count, Length: 30839, dtype: int64
#
#
# review_id
# R1QXC7AHHJBQ3O    1
# R175VSRV6ZETOP    1
# R2HRFF78MWGY19    1
# R8Q39WPKYVSTX     1
# R3RL4C8YP2ZCJL    1
#                  ..
# R366C7ARIWLN7R    1
# R35PL0AOCUXLU9    1
# R18ZJVY86AUFII    1
# R36QVLQXMCZRSJ    1
# R1MWVQUDBUADGE    1
# Name: count, Length: 30840, dtype: int64
#
#
# product_id
# B00IKPYKWG    12153
# B00IKPW0UA     6271
# B00IKPZ5V6     2399
# B00LCHS1FG     1759
# B00LCHOCZY     1755
# B00LCI2I7C     1160
# B00LCHRQL6     1126
# B00LCHWEPE      824
# B00KC6XV58      819
# B00LCHSHMS      609
# B00KC89C2C      607
# B00IKPX4GY      342
# B00LCHNAA2      207
# B00LCI3LUA      148
# B00LCHN19C      138
# B00LCHNGZG      137
# B00KC6Y1MU      134
# ...

# %%
data = data.drop('sentiment', axis=1) #A coluna sentimento não será utilizada para análise

# %%
import seaborn as sns
import matplotlib.pyplot as plt #Distribuição de estrelas por quantidade de itens

# %%
data['review_length'] = data['review_body'].str.len()

# %%
sns.histplot(data['review_length'], bins=50)
plt.xlim(0, 1000)
plt.title('Distribuição (até 1000 caracteres)')
plt.show()
#Distribuição de caracteres por review

# %%
plt.hist(data['star_rating'], bins=5)
plt.xlabel('Estrelas')
plt.ylabel('Quantidade')
plt.title('Distribuição de Avaliações')
plt.show()

# %%
from wordcloud import WordCloud

# %%
text = " ".join(data['review_body'].astype(str))
wc = WordCloud(width=800, height=400).generate(text)

plt.imshow(wc)
plt.axis('off')
plt.title('Palavras Mais Frequentes')
plt.show()
#Palavras mais usadas por review

# %%
text = " ".join(data['review_headline'].astype(str))
 
wc = WordCloud(width=800, height=400).generate(text)
 
plt.imshow(wc)
plt.axis('off')
plt.title('Palavras Mais Frequentes')
plt.show()

# %% [markdown]
# ## Iniciando script de análise de sentimento

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\SarmentoHenrique(Bip\AppData\Roaming\nltk_dat
# [nltk_data]     a...
# True

# %%
# Inicializa o analisador de sentimentos
sia = SentimentIntensityAnalyzer()

def classificar_sentimento(texto):
    """
    Função que recebe um texto, calcula o 'compound score' usando o VADER
    e retorna a classificação (POSITIVO, NEUTRO, NEGATIVO).
    """
    # Trata valores nulos/vazios caso existam no CSV
    if pd.isna(texto):
        return 'NEUTRO'
    
    # Calcula a polaridade. Retorna um dicionário e extraímos a chave 'compound'
    score = sia.polarity_scores(str(texto))['compound']
    
    # Aplica as regras de negócio de acordo com a pontuação
    if score >= 0.05:
        return 'POSITIVO'
    elif score <= -0.05:
        return 'NEGATIVO'
    else:
        return 'NEUTRO'

# %%
# Calculando o sentimento de cada parte
data['headline_sentimento'] = data['review_headline'].apply(classificar_sentimento)
data['body_sentimento'] = data['review_body'].apply(classificar_sentimento)

# Criando uma coluna para analise do sentimento geral, combinando headline e body
data['review_completa'] = data['review_headline'].fillna('') + ". " + data['review_body'].fillna('')
data['sentimento_geral'] = data['review_completa'].apply(classificar_sentimento)

# %%
# Configurar o estilo visual do Seaborn
sns.set_theme(style="whitegrid")
# Definir uma paleta de cores padrão para manter consistência
cores = {'POSITIVO': '#2ecc71', 'NEUTRO': '#95a5a6', 'NEGATIVO': '#e74c3c'}
ordem_categorias = ['POSITIVO', 'NEUTRO', 'NEGATIVO']

# Criar uma figura com 3 subgráficos (1 linha, 3 colunas)
fig, axes = plt.subplots(1, 3, figsize=(18, 6), sharey=True)
fig.suptitle('Análise de Sentimentos das Avaliações (VADER)', fontsize=20, fontweight='bold')

# Gráfico 1: Headline (Título)
sns.countplot(
    data=data, 
    x='headline_sentimento', 
    ax=axes[0], 
    order=ordem_categorias, 
    palette=cores
)
axes[0].set_title('Sentimento do Título (Headline)', fontsize=14)
axes[0].set_xlabel('Classificação')
axes[0].set_ylabel('Quantidade de Avaliações')

# Gráfico 2: Body (Corpo)
sns.countplot(
    data=data, 
    x='body_sentimento', 
    ax=axes[1], 
    order=ordem_categorias, 
    palette=cores
)
axes[1].set_title('Sentimento do Texto (Body)', fontsize=14)
axes[1].set_xlabel('Classificação')
axes[1].set_ylabel('')

# Gráfico 3: Sentimento Geral
sns.countplot(
    data=data, 
    x='sentimento_geral', 
    ax=axes[2], 
    order=ordem_categorias, 
    palette=cores
)
axes[2].set_title('Sentimento Geral', fontsize=14)
axes[2].set_xlabel('Classificação')
axes[2].set_ylabel('')

# Adicionar os rótulos de dados (valores em cima de cada barra)
for ax in axes:
    for p in ax.patches:
        height = p.get_height()
        if height > 0: # Para não mostrar 0 em barras vazias
            ax.annotate(f'{int(height)}', 
                        (p.get_x() + p.get_width() / 2., height), 
                        ha='center', va='bottom', 
                        fontsize=12, fontweight='bold', color='black', 
                        xytext=(0, 5), textcoords='offset points')

# Ajustar o layout para não cortar textos
plt.tight_layout(rect=[0, 0, 1, 0.95])

# Salvar o gráfico como imagem e exibi-lo
nome_imagem = 'resultado_sentimentos.png'
plt.savefig(nome_imagem, dpi=300)

plt.show()
# Out:
# C:\Users\SarmentoHenrique(Bip\AppData\Local\Temp\ipykernel_29392\163626022.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(
# C:\Users\SarmentoHenrique(Bip\AppData\Local\Temp\ipykernel_29392\163626022.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(
# C:\Users\SarmentoHenrique(Bip\AppData\Local\Temp\ipykernel_29392\163626022.py:36: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(

# %%
# Calculo de acurácia do modelo utilizando o star_rating como base de comparação
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
# Criando o gabarito baseado nas estrelas
def mapear_estrelas_para_sentimento(nota):
    if nota >= 4: return 'POSITIVO'
    elif nota <= 3: return 'NEGATIVO'
    else: return 'NEUTRO'

data['sentimento_real'] = data['star_rating'].apply(mapear_estrelas_para_sentimento)

# Calculando a Acurácia do 'body_sentimento' contra o gabarito
acuracia = accuracy_score(data['sentimento_real'], data['body_sentimento'])
print(f"Acurácia do VADER (Body): {acuracia:.2%}")

# Gerando o relatório detalhado
print("\nRelatório de Classificação:")
print(classification_report(data['sentimento_real'], data['body_sentimento']))
# Out:
# Acurácia do VADER (Body): 81.99%
#
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#     NEGATIVO       0.65      0.43      0.51      5077
#       NEUTRO       0.00      0.00      0.00         0
#     POSITIVO       0.91      0.90      0.90     25763
#
#     accuracy                           0.82     30840
#    macro avg       0.52      0.44      0.47     30840
# weighted avg       0.87      0.82      0.84     30840
# C:\Users\SarmentoHenrique(Bip\AppData\Roaming\Python\Python313\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# ...

# %%
# Calculando a Acurácia do 'headline_sentimento' contra o gabarito
acuracia = accuracy_score(data['sentimento_real'], data['headline_sentimento'])
print(f"Acurácia do VADER (Body): {acuracia:.2%}")

# Gerando o relatório detalhado
print("\nRelatório de Classificação:")
print(classification_report(data['sentimento_real'], data['headline_sentimento']))
# Out:
# Acurácia do VADER (Body): 43.59%
#
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#     NEGATIVO       0.57      0.33      0.41      5077
#       NEUTRO       0.00      0.00      0.00         0
#     POSITIVO       0.90      0.46      0.61     25763
#
#     accuracy                           0.44     30840
#    macro avg       0.49      0.26      0.34     30840
# weighted avg       0.84      0.44      0.57     30840
# C:\Users\SarmentoHenrique(Bip\AppData\Roaming\Python\Python313\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# ...

# %%
# Calculando a Acurácia do 'sentimento_geral' contra o gabarito
acuracia = accuracy_score(data['sentimento_real'], data['sentimento_geral'])
print(f"Acurácia do VADER (Body): {acuracia:.2%}")

# Gerando o relatório detalhado
print("\nRelatório de Classificação:")
print(classification_report(data['sentimento_real'], data['sentimento_geral']))
# Out:
# Acurácia do VADER (Body): 83.42%
#
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#     NEGATIVO       0.67      0.44      0.53      5077
#       NEUTRO       0.00      0.00      0.00         0
#     POSITIVO       0.91      0.91      0.91     25763
#
#     accuracy                           0.83     30840
#    macro avg       0.53      0.45      0.48     30840
# weighted avg       0.87      0.83      0.85     30840
# C:\Users\SarmentoHenrique(Bip\AppData\Roaming\Python\Python313\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# ...
